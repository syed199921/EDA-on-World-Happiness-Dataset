# %%
import pandas as pd
import glob
import os

# %%
reports_csv_files = glob.glob("data/raw/data/*.csv") 
print("Reports", reports_csv_files)
# Out:
# Reports ['data/raw/data\\2015.csv', 'data/raw/data\\2016.csv', 'data/raw/data\\2017.csv', 'data/raw/data\\2018.csv', 'data/raw/data\\2019.csv']

# %%
dfs = []
for file in reports_csv_files:
    year = os.path.basename(file).split('.')[0]
    print('year',year)
    df_year = pd.read_csv(file)
    df_year['year'] = year
    dfs.append(df_year)
df = pd.concat(dfs, ignore_index=True)
# Out:
# year 2015
# year 2016
# year 2017
# year 2018
# year 2019

# %%
df.tail()
# Out:
#     Country Region  Happiness Rank  Happiness Score  Standard Error  \
# 777     NaN    NaN             NaN              NaN             NaN
# 778     NaN    NaN             NaN              NaN             NaN
# 779     NaN    NaN             NaN              NaN             NaN
# 780     NaN    NaN             NaN              NaN             NaN
# 781     NaN    NaN             NaN              NaN             NaN
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 777                       NaN     NaN                       NaN      NaN
# 778                       NaN     NaN                       NaN      NaN
# 779                       NaN     NaN                       NaN      NaN
# 780                       NaN     NaN                       NaN      NaN
# 781                       NaN     NaN                       NaN      NaN
#
#      Trust (Government Corruption)  ...  Trust..Government.Corruption.  \
# ...

# %%
df
# Out:
#          Country          Region  Happiness Rank  Happiness Score  \
# 0    Switzerland  Western Europe             1.0            7.587
# 1        Iceland  Western Europe             2.0            7.561
# 2        Denmark  Western Europe             3.0            7.527
# 3         Norway  Western Europe             4.0            7.522
# 4         Canada   North America             5.0            7.427
# ..           ...             ...             ...              ...
# 777          NaN             NaN             NaN              NaN
# 778          NaN             NaN             NaN              NaN
# 779          NaN             NaN             NaN              NaN
# 780          NaN             NaN             NaN              NaN
# 781          NaN             NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  ...  \
# 0                   0.94143  0.66557                        0.41978  ...
# 1                   0.94784  0.62877                        0.14145  ...
# ...

# %%
df.shape
# Out:
# (782, 31)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'year', 'Lower Confidence Interval',
#        'Upper Confidence Interval', 'Happiness.Rank', 'Happiness.Score',
#        'Whisker.high', 'Whisker.low', 'Economy..GDP.per.Capita.',
#        'Health..Life.Expectancy.', 'Trust..Government.Corruption.',
#        'Dystopia.Residual', 'Overall rank', 'Country or region', 'Score',
#        'GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Perceptions of corruption'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      315.000000       315.000000      158.000000
# mean        79.238095         5.378949        0.047885
# std         45.538922         1.141531        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.000000         4.510000        0.037268
# 50%         79.000000         5.286000        0.043940
# 75%        118.500000         6.269000        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                315.000000  470.000000                315.000000
# mean                   0.899837    0.990347                  0.594054
# std                    0.410780    0.318707                  0.240790
# min                    0.000000    0.000000                  0.000000
# 25%                    0.594900    0.793000                  0.419645
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        470 non-null    object
#  1   Region                         315 non-null    object
#  2   Happiness Rank                 315 non-null    float64
#  3   Happiness Score                315 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       315 non-null    float64
#  6   Family                         470 non-null    float64
#  7   Health (Life Expectancy)       315 non-null    float64
#  8   Freedom                        470 non-null    float64
#  9   Trust (Government Corruption)  315 non-null    float64
#  10  Generosity                     782 non-null    float64
#  11  Dystopia Residual              315 non-null    float64
# ...

# %%
df.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 777     True    True            True             True            True
# 778     True    True            True             True            True
# 779     True    True            True             True            True
# 780     True    True            True             True            True
# 781     True    True            True             True            True
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                          312
# Region                           467
# Happiness Rank                   467
# Happiness Score                  467
# Standard Error                   624
# Economy (GDP per Capita)         467
# Family                           312
# Health (Life Expectancy)         467
# Freedom                          312
# Trust (Government Corruption)    467
# Generosity                         0
# Dystopia Residual                467
# year                               0
# Lower Confidence Interval        625
# Upper Confidence Interval        625
# Happiness.Rank                   627
# Happiness.Score                  627
# Whisker.high                     627
# Whisker.low                      627
# Economy..GDP.per.Capita.         627
# Health..Life.Expectancy.         627
# Trust..Government.Corruption.    627
# Dystopia.Residual                627
# Overall rank                     470
# Country or region                470
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  ...  \
# 0                   0.94143  0.66557                        0.41978  ...
# 1                   0.94784  0.62877                        0.14145  ...
# ...

# %%
# Sample list of original columns
original_columns = [
    'Country', 'Region', 'Happiness Rank', 'Happiness Score',
    'Standard Error', 'Economy (GDP per Capita)', 'Family',
    'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
    'Generosity', 'Dystopia Residual', 'year', 'Lower Confidence Interval',
    'Upper Confidence Interval', 'Happiness.Rank', 'Happiness.Score',
    'Whisker.high', 'Whisker.low', 'Economy..GDP.per.Capita.',
    'Health..Life.Expectancy.', 'Trust..Government.Corruption.',
    'Dystopia.Residual', 'Overall rank', 'Country or region', 'Score',
    'GDP per capita', 'Social support', 'Healthy life expectancy',
    'Freedom to make life choices', 'Perceptions of corruption'
]

# %%
# Canonical mapping dictionary
canonical_map = {
    'Country': 'country',
    'Country or region': 'country',
    'Region': 'region',
    'Happiness Rank': 'happiness_rank',
    'Overall rank': 'happiness_rank',
    'Happiness Score': 'happiness_score',
    'Happiness.Score': 'happiness_score',
    'Score': 'happiness_score',
    'Standard Error': 'standard_error',
    'Economy (GDP per Capita)': 'log_gdp_per_capita',
    'Economy..GDP.per.Capita.': 'log_gdp_per_capita',
    'GDP per capita': 'log_gdp_per_capita',
    'Family': 'family',
    'Social support': 'social_support',
    'Health (Life Expectancy)': 'healthy_life_expectancy',
    'Health..Life.Expectancy.': 'healthy_life_expectancy',
    'Healthy life expectancy': 'healthy_life_expectancy',
    'Freedom': 'freedom',
    'Freedom to make life choices': 'freedom',
    'Trust (Government Corruption)': 'perceptions_of_corruption',
    'Trust..Government.Corruption.': 'perceptions_of_corruption',
    'Perceptions of corruption': 'perceptions_of_corruption',
    'Generosity': 'generosity',
    'Dystopia Residual': 'dystopia_residual',
    'Dystopia.Residual': 'dystopia_residual',
    'Whisker.high': 'whisker_high',
    'Whisker.low': 'whisker_low',
    'Lower Confidence Interval': 'lower_confidence_interval',
    'Upper Confidence Interval': 'upper_confidence_interval',
    'year': 'year'
}

# %%
def standardize_column_names(df):
    return df.rename(columns=lambda col:canonical_map.get(col, col.strip().lower().replace(" ", "_").replace(".","_")))

# %%
df_modified = standardize_column_names(df)

# %%
df_modified.head()
# Out:
#        country          region happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe            1.0            7.587
# 1      Iceland  Western Europe            2.0            7.561
# 2      Denmark  Western Europe            3.0            7.527
# 3       Norway  Western Europe            4.0            7.522
# 4       Canada   North America            5.0            7.427
#
#    standard_error  log_gdp_per_capita   family  healthy_life_expectancy  \
# 0         0.03411             1.39651  1.34951                  0.94143
# 1         0.04884             1.30232  1.40223                  0.94784
# 2         0.03328             1.32548  1.36058                  0.87464
# 3         0.03880             1.45900  1.33095                  0.88521
# 4         0.03553             1.32629  1.32261                  0.90563
#
#    freedom  perceptions_of_corruption  ...  perceptions_of_corruption  \
# 0  0.66557                    0.41978  ...                        NaN
# ...

# %%
df_modified
# Out:
#          country          region  happiness_rank  standard_error  \
# 0    Switzerland  Western Europe             1.0         0.03411
# 1        Iceland  Western Europe             2.0         0.04884
# 2        Denmark  Western Europe             3.0         0.03328
# 3         Norway  Western Europe             4.0         0.03880
# 4         Canada   North America             5.0         0.03553
# ..           ...             ...             ...             ...
# 777                                          NaN             NaN
# 778                                          NaN             NaN
# 779                                          NaN             NaN
# 780                                          NaN             NaN
# 781                                          NaN             NaN
#
#      log_gdp_per_capita   family  healthy_life_expectancy  freedom  \
# 0               1.39651  1.34951                  0.94143  0.66557
# ...

# %%
happiness_score_cols = [col for col in df_modified.columns if col == 'happiness_score']

if len(happiness_score_cols) > 1:
    df_modified['happiness_score_merged'] = df_modified[happiness_score_cols].bfill(axis=1).iloc[:,0]
    df_modified = df_modified.drop(columns=happiness_score_cols)
    df_modified = df_modified.rename(columns={'happiness_score_merged': 'happiness_score'})

# %%
df_modified['happiness_score']
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 777    3.334
# 778    3.231
# 779    3.203
# 780    3.083
# 781    2.853
# Name: happiness_score, Length: 782, dtype: float64

# %%
df_modified
# Out:
#          country          region  happiness_rank  standard_error  \
# 0    Switzerland  Western Europe             1.0         0.03411
# 1        Iceland  Western Europe             2.0         0.04884
# 2        Denmark  Western Europe             3.0         0.03328
# 3         Norway  Western Europe             4.0         0.03880
# 4         Canada   North America             5.0         0.03553
# ..           ...             ...             ...             ...
# 777                                          NaN             NaN
# 778                                          NaN             NaN
# 779                                          NaN             NaN
# 780                                          NaN             NaN
# 781                                          NaN             NaN
#
#      log_gdp_per_capita   family  healthy_life_expectancy  freedom  \
# 0               1.39651  1.34951                  0.94143  0.66557
# ...

# %%
df_modified.columns
# Out:
# Index(['country', 'region', 'happiness_rank', 'standard_error',
#        'log_gdp_per_capita', 'family', 'healthy_life_expectancy', 'freedom',
#        'perceptions_of_corruption', 'generosity', 'dystopia_residual', 'year',
#        'lower_confidence_interval', 'upper_confidence_interval',
#        'happiness_rank', 'whisker_high', 'whisker_low', 'log_gdp_per_capita',
#        'healthy_life_expectancy', 'perceptions_of_corruption',
#        'dystopia_residual', 'happiness_rank', 'country', 'log_gdp_per_capita',
#        'social_support', 'healthy_life_expectancy', 'freedom',
#        'perceptions_of_corruption', 'happiness_score'],
#       dtype='object')

# %%
df_modified.columns[df_modified.columns.duplicated()]
# Out:
# Index(['happiness_rank', 'log_gdp_per_capita', 'healthy_life_expectancy',
#        'perceptions_of_corruption', 'dystopia_residual', 'happiness_rank',
#        'country', 'log_gdp_per_capita', 'healthy_life_expectancy', 'freedom',
#        'perceptions_of_corruption'],
#       dtype='object')

# %%
happiness_rank_cols = [col for col in df_modified.columns if col == 'happiness_rank']

# %%
happiness_rank_cols
# Out:
# ['happiness_rank', 'happiness_rank', 'happiness_rank']

# %%
df_modified['happiness_rank']
# Out:
#      happiness_rank  happiness_rank  happiness_rank
# 0               1.0             NaN             NaN
# 1               2.0             NaN             NaN
# 2               3.0             NaN             NaN
# 3               4.0             NaN             NaN
# 4               5.0             NaN             NaN
# ..              ...             ...             ...
# 777             NaN             NaN           152.0
# 778             NaN             NaN           153.0
# 779             NaN             NaN           154.0
# 780             NaN             NaN           155.0
# 781             NaN             NaN           156.0
#
# [782 rows x 3 columns]

# %%
happiness_rank_cols = [col for col in df_modified.columns if col == 'happiness_rank']
df_modified['happiness_rank_merged'] = df_modified[happiness_rank_cols].bfill(axis=1).iloc[:,0]

# %%
df_modified = df_modified.drop(columns=happiness_rank_cols)

# %%
df_modified = df_modified.rename(columns={"happiness_rank_merged":"happiness_rank"})

# %%
df_modified['country'] == 'Findland'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 777    False
# 778    False
# 779    False
# 780    False
# 781    False
# Name: country, Length: 782, dtype: bool

# %%
df_modified['log_gdp_per_capita']
# Out:
#      log_gdp_per_capita  log_gdp_per_capita  log_gdp_per_capita
# 0               1.39651                 NaN                 NaN
# 1               1.30232                 NaN                 NaN
# 2               1.32548                 NaN                 NaN
# 3               1.45900                 NaN                 NaN
# 4               1.32629                 NaN                 NaN
# ..                  ...                 ...                 ...
# 777                 NaN                 NaN               0.359
# 778                 NaN                 NaN               0.476
# 779                 NaN                 NaN               0.350
# 780                 NaN                 NaN               0.026
# 781                 NaN                 NaN               0.306
#
# [782 rows x 3 columns]

# %%
log_gdp_per_capita_cols= [col for col in df_modified.columns if col == 'log_gdp_per_capita']

if len(log_gdp_per_capita_cols) > 1:
    df_modified['log_gdp_per_capita_merged'] = df_modified[log_gdp_per_capita_cols].bfill(axis=1).iloc[:,0]
    df_modified = df_modified.drop(columns=log_gdp_per_capita_cols)
    df_modified = df_modified.rename(columns={'log_gdp_per_capita_merged': 'log_gdp_per_capita'})

# %%
df_modified['healthy_life_expectancy']
# Out:
#      healthy_life_expectancy  healthy_life_expectancy  healthy_life_expectancy
# 0                    0.94143                      NaN                      NaN
# 1                    0.94784                      NaN                      NaN
# 2                    0.87464                      NaN                      NaN
# 3                    0.88521                      NaN                      NaN
# 4                    0.90563                      NaN                      NaN
# ..                       ...                      ...                      ...
# 777                      NaN                      NaN                    0.614
# 778                      NaN                      NaN                    0.499
# 779                      NaN                      NaN                    0.361
# 780                      NaN                      NaN                    0.105
# 781                      NaN                      NaN                    0.295
#
# [782 rows x 3 columns]

# %%
healthy_life_expectancy_cols= [col for col in df_modified.columns if col == 'healthy_life_expectancy']

if len(healthy_life_expectancy_cols) > 1:
    df_modified['healthy_life_expectancy_merged'] = df_modified[healthy_life_expectancy_cols].bfill(axis=1).iloc[:,0]
    df_modified = df_modified.drop(columns=healthy_life_expectancy_cols)
    df_modified = df_modified.rename(columns={'healthy_life_expectancy_merged': 'healthy_life_expectancy'})

# %%
df_modified['perceptions_of_corruption']
# Out:
#      perceptions_of_corruption  perceptions_of_corruption  \
# 0                      0.41978                        NaN
# 1                      0.14145                        NaN
# 2                      0.48357                        NaN
# 3                      0.36503                        NaN
# 4                      0.32957                        NaN
# ..                         ...                        ...
# 777                        NaN                        NaN
# 778                        NaN                        NaN
# 779                        NaN                        NaN
# 780                        NaN                        NaN
# 781                        NaN                        NaN
#
#      perceptions_of_corruption
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 777                      0.411
# ...

# %%
perceptions_of_corruption_cols = [col for col in df_modified.columns if col == 'perceptions_of_corruption']

if len(perceptions_of_corruption_cols) > 1:
    df_modified['perceptions_of_corruption_merged'] = df_modified[perceptions_of_corruption_cols].bfill(axis=1).iloc[:, 0]
    df_modified = df_modified.drop(columns=perceptions_of_corruption_cols)
    df_modified = df_modified.rename(columns={'perceptions_of_corruption_merged': 'perceptions_of_corruption'})

# %%
df_modified['dystopia_residual']
# Out:
#      dystopia_residual  dystopia_residual
# 0              2.51738                NaN
# 1              2.70201                NaN
# 2              2.49204                NaN
# 3              2.46531                NaN
# 4              2.45176                NaN
# ..                 ...                ...
# 777                NaN                NaN
# 778                NaN                NaN
# 779                NaN                NaN
# 780                NaN                NaN
# 781                NaN                NaN
#
# [782 rows x 2 columns]

# %%
dystopia_residual_cols = [col for col in df_modified.columns if col == 'dystopia_residual']

if len(dystopia_residual_cols) > 1:
    df_modified['dystopia_residual_merged'] = df_modified[dystopia_residual_cols].bfill(axis=1).iloc[:, 0]
    df_modified = df_modified.drop(columns=dystopia_residual_cols)
    df_modified = df_modified.rename(columns={'dystopia_residual_merged': 'dystopia_residual'})

# %%
df_modified['country']
# Out:
#          country                   country
# 0    Switzerland
# 1        Iceland
# 2        Denmark
# 3         Norway
# 4         Canada
# ..           ...                       ...
# 777                                 Rwanda
# 778                               Tanzania
# 779                            Afghanistan
# 780               Central African Republic
# 781                            South Sudan
#
# [782 rows x 2 columns]

# %%
country_cols = [col for col in df_modified.columns if col == 'country']

if len(country_cols) > 1:
    df_modified['country_merged'] = df_modified[country_cols].bfill(axis=1).iloc[:, 0]
    df_modified = df_modified.drop(columns=country_cols)
    df_modified = df_modified.rename(columns={'country_merged': 'country'})

# %%
df_modified['country']
# Out:
# 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 777
# 778
# 779
# 780
# 781
# Name: country, Length: 782, dtype: object

# %%
'South Sudan' in df_modified['country'].values
# Out:
# True

# %%
df
# Out:
#          Country          Region  Happiness Rank  Happiness Score  \
# 0    Switzerland  Western Europe             1.0            7.587
# 1        Iceland  Western Europe             2.0            7.561
# 2        Denmark  Western Europe             3.0            7.527
# 3         Norway  Western Europe             4.0            7.522
# 4         Canada   North America             5.0            7.427
# ..           ...             ...             ...              ...
# 777          NaN             NaN             NaN              NaN
# 778          NaN             NaN             NaN              NaN
# 779          NaN             NaN             NaN              NaN
# 780          NaN             NaN             NaN              NaN
# 781          NaN             NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# ...

# %%
df_modified['country']
# Out:
# 0                   Switzerland
# 1                       Iceland
# 2                       Denmark
# 3                        Norway
# 4                        Canada
#                  ...
# 777                      Rwanda
# 778                    Tanzania
# 779                 Afghanistan
# 780    Central African Republic
# 781                 South Sudan
# Name: country, Length: 782, dtype: object

# %%
df_modified['freedom']
# Out:
#      freedom  freedom
# 0    0.66557      NaN
# 1    0.62877      NaN
# 2    0.64938      NaN
# 3    0.66973      NaN
# 4    0.63297      NaN
# ..       ...      ...
# 777      NaN    0.555
# 778      NaN    0.417
# 779      NaN    0.000
# 780      NaN    0.225
# 781      NaN    0.010
#
# [782 rows x 2 columns]

# %%
freedom_cols = [col for col in df_modified.columns if col == 'freedom']

if len(freedom_cols) > 1:
    df_modified['freedom_merged'] = df_modified[freedom_cols].bfill(axis=1).iloc[:, 0]
    df_modified = df_modified.drop(columns=freedom_cols)
    df_modified = df_modified.rename(columns={'freedom_merged': 'freedom'})

# %%
df_modified
# Out:
#              region  standard_error   family  generosity  year  \
# 0    Western Europe         0.03411  1.34951     0.29678  2015
# 1    Western Europe         0.04884  1.40223     0.43630  2015
# 2    Western Europe         0.03328  1.36058     0.34139  2015
# 3    Western Europe         0.03880  1.33095     0.34699  2015
# 4     North America         0.03553  1.32261     0.45811  2015
# ..              ...             ...      ...         ...   ...
# 777             NaN             NaN      NaN     0.21700  2019
# 778             NaN             NaN      NaN     0.27600  2019
# 779             NaN             NaN      NaN     0.15800  2019
# 780             NaN             NaN      NaN     0.23500  2019
# 781             NaN             NaN      NaN     0.20200  2019
#
#      lower_confidence_interval  upper_confidence_interval  whisker_high  \
# 0                          NaN                        NaN           NaN
# ...

# %%
df_modified.columns[df_modified.columns.duplicated()]
# Out:
# Index([], dtype='object')

# %%
'Pakistan' in df_modified['country'].values
# Out:
# False

# %%
df_modified[df_modified['country'] == 'Pakistan']
# Out:
#             region  standard_error    family  generosity  year  \
# 80   Southern Asia         0.03726  0.414110    0.336710  2015
# 249  Southern Asia             NaN  0.261350    0.311850  2016
# 394            NaN             NaN  0.672691    0.315446  2017
# 544            NaN             NaN       NaN    0.216000  2018
# 692            NaN             NaN       NaN    0.220000  2019
#
#      lower_confidence_interval  upper_confidence_interval  whisker_high  \
# 80                         NaN                        NaN           NaN
# 249                      5.038                      5.226           NaN
# 394                        NaN                        NaN      5.359984
# 544                        NaN                        NaN           NaN
# 692                        NaN                        NaN           NaN
#
#      whisker_low  social_support  happiness_score  happiness_rank  \
# 80           NaN             NaN            5.194            81.0
# ...

# %%
 str_cols = df_modified.select_dtypes(include="object").columns

# %%
for col in str_cols:
    df_modified[col] = df_modified[col].astype(str).replace({"nan":"", "None":""})

# %%
df_modified[df_modified['country'] == ""]
# Out:
# Empty DataFrame
# Columns: [region, standard_error, family, generosity, year, lower_confidence_interval, upper_confidence_interval, whisker_high, whisker_low, social_support, happiness_score, happiness_rank, log_gdp_per_capita, healthy_life_expectancy, perceptions_of_corruption, dystopia_residual, country, freedom]
# Index: []

# %%
# Convert numeric-ish columns robustly
numeric_cols = df_modified.select_dtypes(include="float").columns

# %%
for col in numeric_cols:
    df_modified[col] = pd.to_numeric(df_modified[col], errors="coerce")

# %%
df_modified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   region                     782 non-null    object
#  1   standard_error             158 non-null    float64
#  2   family                     470 non-null    float64
#  3   generosity                 782 non-null    float64
#  4   year                       782 non-null    Int64
#  5   lower_confidence_interval  157 non-null    float64
#  6   upper_confidence_interval  157 non-null    float64
#  7   whisker_high               155 non-null    float64
#  8   whisker_low                155 non-null    float64
#  9   social_support             312 non-null    float64
#  10  happiness_score            782 non-null    float64
#  11  happiness_rank             782 non-null    float64
#  12  log_gdp_per_capita         782 non-null    float64
# ...

# %%
df_modified["year"] = pd.to_numeric(df_modified["year"], errors='coerce').astype("Int64")

# %%
df_modified
# Out:
#              region  standard_error   family  generosity  year  \
# 0    Western Europe         0.03411  1.34951     0.29678  2015
# 1    Western Europe         0.04884  1.40223     0.43630  2015
# 2    Western Europe         0.03328  1.36058     0.34139  2015
# 3    Western Europe         0.03880  1.33095     0.34699  2015
# 4     North America         0.03553  1.32261     0.45811  2015
# ..              ...             ...      ...         ...   ...
# 777                             NaN      NaN     0.21700  2019
# 778                             NaN      NaN     0.27600  2019
# 779                             NaN      NaN     0.15800  2019
# 780                             NaN      NaN     0.23500  2019
# 781                             NaN      NaN     0.20200  2019
#
#      lower_confidence_interval  upper_confidence_interval  whisker_high  \
# 0                          NaN                        NaN           NaN
# ...

# %%
df_modified.dtypes
# Out:
# region                        object
# standard_error               float64
# family                       float64
# generosity                   float64
# year                           Int64
# lower_confidence_interval    float64
# upper_confidence_interval    float64
# whisker_high                 float64
# whisker_low                  float64
# social_support               float64
# happiness_score              float64
# happiness_rank               float64
# log_gdp_per_capita           float64
# healthy_life_expectancy      float64
# perceptions_of_corruption    float64
# dystopia_residual            float64
# country                       object
# freedom                      float64
# dtype: object

# %%
df_modified
# Out:
#              region  standard_error   family  generosity  year  \
# 0    Western Europe         0.03411  1.34951     0.29678  2015
# 1    Western Europe         0.04884  1.40223     0.43630  2015
# 2    Western Europe         0.03328  1.36058     0.34139  2015
# 3    Western Europe         0.03880  1.33095     0.34699  2015
# 4     North America         0.03553  1.32261     0.45811  2015
# ..              ...             ...      ...         ...   ...
# 777                             NaN      NaN     0.21700  2019
# 778                             NaN      NaN     0.27600  2019
# 779                             NaN      NaN     0.15800  2019
# 780                             NaN      NaN     0.23500  2019
# 781                             NaN      NaN     0.20200  2019
#
#      lower_confidence_interval  upper_confidence_interval  whisker_high  \
# 0                          NaN                        NaN           NaN
# ...

# %%
df_modified.to_csv('eda_analysis.csv', index=False)

# %%
df_modified.isnull().sum()
# Out:
# region                         0
# standard_error               624
# family                       312
# generosity                     0
# year                           0
# lower_confidence_interval    625
# upper_confidence_interval    625
# whisker_high                 627
# whisker_low                  627
# social_support               470
# happiness_score                0
# happiness_rank                 0
# log_gdp_per_capita             0
# healthy_life_expectancy        0
# perceptions_of_corruption      1
# dystopia_residual            312
# country                        0
# freedom                        0
# dtype: int64

# %%
df_mod = df_modified

# %%
df_mod
# Out:
#              region  standard_error   family  generosity  year  \
# 0    Western Europe         0.03411  1.34951     0.29678  2015
# 1    Western Europe         0.04884  1.40223     0.43630  2015
# 2    Western Europe         0.03328  1.36058     0.34139  2015
# 3    Western Europe         0.03880  1.33095     0.34699  2015
# 4     North America         0.03553  1.32261     0.45811  2015
# ..              ...             ...      ...         ...   ...
# 777                             NaN      NaN     0.21700  2019
# 778                             NaN      NaN     0.27600  2019
# 779                             NaN      NaN     0.15800  2019
# 780                             NaN      NaN     0.23500  2019
# 781                             NaN      NaN     0.20200  2019
#
#      lower_confidence_interval  upper_confidence_interval  whisker_high  \
# 0                          NaN                        NaN           NaN
# ...

# %%
df_mod.isnull().sum()
# Out:
# region                         0
# standard_error               624
# family                       312
# generosity                     0
# year                           0
# lower_confidence_interval    625
# upper_confidence_interval    625
# whisker_high                 627
# whisker_low                  627
# social_support               470
# happiness_score                0
# happiness_rank                 0
# log_gdp_per_capita             0
# healthy_life_expectancy        0
# perceptions_of_corruption      1
# dystopia_residual            312
# country                        0
# freedom                        0
# dtype: int64

# %%
df_mod = df_mod.drop(columns=['standard_error', 'lower_confidence_interval', 'upper_confidence_interval', 'whisker_high', 'whisker_low'])

# %%
df_mod
# Out:
#              region   family  generosity  year  social_support  \
# 0    Western Europe  1.34951     0.29678  2015             NaN
# 1    Western Europe  1.40223     0.43630  2015             NaN
# 2    Western Europe  1.36058     0.34139  2015             NaN
# 3    Western Europe  1.33095     0.34699  2015             NaN
# 4     North America  1.32261     0.45811  2015             NaN
# ..              ...      ...         ...   ...             ...
# 777                      NaN     0.21700  2019           0.711
# 778                      NaN     0.27600  2019           0.885
# 779                      NaN     0.15800  2019           0.517
# 780                      NaN     0.23500  2019           0.000
# 781                      NaN     0.20200  2019           0.575
#
#      happiness_score  happiness_rank  log_gdp_per_capita  \
# 0              7.587             1.0             1.39651
# 1              7.561             2.0             1.30232
# ...

# %%
import numpy as np
df_mod['region'] = df_mod['region'].replace("",np.nan)

# %%
df_mod[['region','country']]
# Out:
#              region                   country
# 0    Western Europe               Switzerland
# 1    Western Europe                   Iceland
# 2    Western Europe                   Denmark
# 3    Western Europe                    Norway
# 4     North America                    Canada
# ..              ...                       ...
# 777             NaN                    Rwanda
# 778             NaN                  Tanzania
# 779             NaN               Afghanistan
# 780             NaN  Central African Republic
# 781             NaN               South Sudan
#
# [782 rows x 2 columns]

# %%
missing = df_mod[df_mod['region'].isnull()]

# %%
missing_countries = missing[missing['region'].isnull()]

# %%
missing['country']
# Out:
# array(['Norway', 'Denmark', 'Iceland', 'Switzerland', 'Finland',
#        'Netherlands', 'Canada', 'New Zealand', 'Sweden', 'Australia',
#        'Israel', 'Costa Rica', 'Austria', 'United States', 'Ireland',
#        'Germany', 'Belgium', 'Luxembourg', 'United Kingdom', 'Chile',
#        'United Arab Emirates', 'Brazil', 'Czech Republic', 'Argentina',
#        'Mexico', 'Singapore', 'Malta', 'Uruguay', 'Guatemala', 'Panama',
#        'France', 'Thailand', 'Taiwan Province of China', 'Spain', 'Qatar',
#        'Colombia', 'Saudi Arabia', 'Trinidad and Tobago', 'Kuwait',
#        'Slovakia', 'Bahrain', 'Malaysia', 'Nicaragua', 'Ecuador',
#        'El Salvador', 'Poland', 'Uzbekistan', 'Italy', 'Russia', 'Belize',
#        'Japan', 'Lithuania', 'Algeria', 'Latvia', 'South Korea',
#        'Moldova', 'Romania', 'Bolivia', 'Turkmenistan', 'Kazakhstan',
#        'North Cyprus', 'Slovenia', 'Peru', 'Mauritius', 'Cyprus',
#        'Estonia', 'Belarus', 'Libya', 'Turkey', 'Paraguay',
# ...

# %%
missing_countries['country'].values
# Out:
# array(['Norway', 'Denmark', 'Iceland', 'Switzerland', 'Finland',
#        'Netherlands', 'Canada', 'New Zealand', 'Sweden', 'Australia',
#        'Israel', 'Costa Rica', 'Austria', 'United States', 'Ireland',
#        'Germany', 'Belgium', 'Luxembourg', 'United Kingdom', 'Chile',
#        'United Arab Emirates', 'Brazil', 'Czech Republic', 'Argentina',
#        'Mexico', 'Singapore', 'Malta', 'Uruguay', 'Guatemala', 'Panama',
#        'France', 'Thailand', 'Taiwan Province of China', 'Spain', 'Qatar',
#        'Colombia', 'Saudi Arabia', 'Trinidad and Tobago', 'Kuwait',
#        'Slovakia', 'Bahrain', 'Malaysia', 'Nicaragua', 'Ecuador',
#        'El Salvador', 'Poland', 'Uzbekistan', 'Italy', 'Russia', 'Belize',
#        'Japan', 'Lithuania', 'Algeria', 'Latvia', 'South Korea',
#        'Moldova', 'Romania', 'Bolivia', 'Turkmenistan', 'Kazakhstan',
#        'North Cyprus', 'Slovenia', 'Peru', 'Mauritius', 'Cyprus',
#        'Estonia', 'Belarus', 'Libya', 'Turkey', 'Paraguay',
# ...

# %%
country_to_region = {
    # Western Europe
    'Norway': 'Western Europe', 'Denmark': 'Western Europe', 'Iceland': 'Western Europe',
    'Switzerland': 'Western Europe', 'Finland': 'Western Europe', 'Netherlands': 'Western Europe',
    'Sweden': 'Western Europe', 'Austria': 'Western Europe', 'Ireland': 'Western Europe',
    'Germany': 'Western Europe', 'Belgium': 'Western Europe', 'Luxembourg': 'Western Europe',
    'United Kingdom': 'Western Europe', 'France': 'Western Europe', 'Malta': 'Western Europe',
    'Spain': 'Western Europe', 'Italy': 'Western Europe', 'Portugal': 'Western Europe',
    'Cyprus': 'Western Europe', 'Greece': 'Western Europe',

    # North America
    'Canada': 'North America', 'United States': 'North America',

    # Australia and New Zealand
    'Australia': 'Australia and New Zealand', 'New Zealand': 'Australia and New Zealand',

    # Middle East and Northern Africa
    'Israel': 'Middle East and Northern Africa', 'United Arab Emirates': 'Middle East and Northern Africa',
    'Saudi Arabia': 'Middle East and Northern Africa', 'Qatar': 'Middle East and Northern Africa',
    'Bahrain': 'Middle East and Northern Africa', 'Kuwait': 'Middle East and Northern Africa',
    'Algeria': 'Middle East and Northern Africa', 'Morocco': 'Middle East and Northern Africa',
    'Tunisia': 'Middle East and Northern Africa', 'Libya': 'Middle East and Northern Africa',
    'Lebanon': 'Middle East and Northern Africa', 'Jordan': 'Middle East and Northern Africa',
    'Iraq': 'Middle East and Northern Africa', 'Iran': 'Middle East and Northern Africa',
    'Egypt': 'Middle East and Northern Africa', 'Palestinian Territories': 'Middle East and Northern Africa',
    'Syria': 'Middle East and Northern Africa', 'Yemen': 'Middle East and Northern Africa',

    # Latin America and Caribbean
    'Costa Rica': 'Latin America and Caribbean', 'Chile': 'Latin America and Caribbean',
    'Brazil': 'Latin America and Caribbean', 'Argentina': 'Latin America and Caribbean',
    'Mexico': 'Latin America and Caribbean', 'Uruguay': 'Latin America and Caribbean',
    'Guatemala': 'Latin America and Caribbean', 'Panama': 'Latin America and Caribbean',
    'Colombia': 'Latin America and Caribbean', 'Trinidad and Tobago': 'Latin America and Caribbean',
    'Nicaragua': 'Latin America and Caribbean', 'Ecuador': 'Latin America and Caribbean',
    'El Salvador': 'Latin America and Caribbean', 'Belize': 'Latin America and Caribbean',
    'Bolivia': 'Latin America and Caribbean', 'Venezuela': 'Latin America and Caribbean',
    'Jamaica': 'Latin America and Caribbean', 'Dominican Republic': 'Latin America and Caribbean',
    'Honduras': 'Latin America and Caribbean', 'Paraguay': 'Latin America and Caribbean',
    'Haiti': 'Latin America and Caribbean',

    # Eastern Asia
    'Japan': 'Eastern Asia', 'South Korea': 'Eastern Asia', 'China': 'Eastern Asia',
    'Taiwan': 'Eastern Asia', 'Hong Kong': 'Eastern Asia', 'Mongolia': 'Eastern Asia',

    # Southeastern Asia
    'Singapore': 'Southeastern Asia', 'Thailand': 'Southeastern Asia', 'Malaysia': 'Southeastern Asia',
    'Philippines': 'Southeastern Asia', 'Indonesia': 'Southeastern Asia', 'Vietnam': 'Southeastern Asia',
    'Cambodia': 'Southeastern Asia', 'Myanmar': 'Southeastern Asia', 'Laos': 'Southeastern Asia',

    # Southern Asia
    'India': 'Southern Asia', 'Pakistan': 'Southern Asia', 'Bangladesh': 'Southern Asia',
    'Nepal': 'Southern Asia', 'Bhutan': 'Southern Asia', 'Sri Lanka': 'Southern Asia',
    'Afghanistan': 'Southern Asia',

    # Sub-Saharan Africa
    'Nigeria': 'Sub-Saharan Africa', 'Mauritius': 'Sub-Saharan Africa', 'Namibia': 'Sub-Saharan Africa',
    'Kenya': 'Sub-Saharan Africa', 'Mozambique': 'Sub-Saharan Africa', 'Senegal': 'Sub-Saharan Africa',
    'Zambia': 'Sub-Saharan Africa', 'Gabon': 'Sub-Saharan Africa', 'Ethiopia': 'Sub-Saharan Africa',
    'South Africa': 'Sub-Saharan Africa', 'Cameroon': 'Sub-Saharan Africa', 'Ivory Coast': 'Sub-Saharan Africa',
    'Ghana': 'Sub-Saharan Africa', 'Sudan': 'Sub-Saharan Africa', 'Somalia': 'Sub-Saharan Africa',
    'Mali': 'Sub-Saharan Africa', 'Sierra Leone': 'Sub-Saharan Africa', 'Madagascar': 'Sub-Saharan Africa',
    'Liberia': 'Sub-Saharan Africa', 'Guinea': 'Sub-Saharan Africa', 'Togo': 'Sub-Saharan Africa',
    'Rwanda': 'Sub-Saharan Africa', 'Tanzania': 'Sub-Saharan Africa', 'Burundi': 'Sub-Saharan Africa',
    'Central African Republic': 'Sub-Saharan Africa', 'South Sudan': 'Sub-Saharan Africa',
    'Angola': 'Sub-Saharan Africa', 'Malawi': 'Sub-Saharan Africa', 'Chad': 'Sub-Saharan Africa',
    'Botswana': 'Sub-Saharan Africa', 'Lesotho': 'Sub-Saharan Africa', 'Comoros': 'Sub-Saharan Africa',
    'Swaziland': 'Sub-Saharan Africa', 'Uganda': 'Sub-Saharan Africa', 'Burkina Faso': 'Sub-Saharan Africa',
    'Niger': 'Sub-Saharan Africa',

    # Central and Eastern Europe
    'Czech Republic': 'Central and Eastern Europe', 'Slovakia': 'Central and Eastern Europe',
    'Poland': 'Central and Eastern Europe', 'Hungary': 'Central and Eastern Europe',
    'Romania': 'Central and Eastern Europe', 'Bulgaria': 'Central and Eastern Europe',
    'Moldova': 'Central and Eastern Europe', 'Ukraine': 'Central and Eastern Europe',
    'Belarus': 'Central and Eastern Europe', 'Russia': 'Central and Eastern Europe',
    'Lithuania': 'Central and Eastern Europe', 'Latvia': 'Central and Eastern Europe',
    'Estonia': 'Central and Eastern Europe', 'Croatia': 'Central and Eastern Europe',
    'Serbia': 'Central and Eastern Europe', 'Montenegro': 'Central and Eastern Europe',
    'Bosnia and Herzegovina': 'Central and Eastern Europe', 'North Macedonia': 'Central and Eastern Europe',
    'Kosovo': 'Central and Eastern Europe', 'Albania': 'Central and Eastern Europe',
    'Armenia': 'Central and Eastern Europe', 'Georgia': 'Central and Eastern Europe',
    'Azerbaijan': 'Central and Eastern Europe', 'Turkey': 'Central and Eastern Europe',
    'Turkmenistan': 'Central and Eastern Europe', 'Kazakhstan': 'Central and Eastern Europe',
    'Uzbekistan': 'Central and Eastern Europe', 'Kyrgyzstan': 'Central and Eastern Europe',
    'Tajikistan': 'Central and Eastern Europe'
}

# %%
df_mod['region'] = df_mod.apply(
    lambda row: country_to_region.get(row['country'], row['region']),
    axis=1
)

# %%
df_mod
# Out:
#                  region   family  generosity  year  social_support  \
# 0        Western Europe  1.34951     0.29678  2015             NaN
# 1        Western Europe  1.40223     0.43630  2015             NaN
# 2        Western Europe  1.36058     0.34139  2015             NaN
# 3        Western Europe  1.33095     0.34699  2015             NaN
# 4         North America  1.32261     0.45811  2015             NaN
# ..                  ...      ...         ...   ...             ...
# 777  Sub-Saharan Africa      NaN     0.21700  2019           0.711
# 778  Sub-Saharan Africa      NaN     0.27600  2019           0.885
# 779       Southern Asia      NaN     0.15800  2019           0.517
# 780  Sub-Saharan Africa      NaN     0.23500  2019           0.000
# 781  Sub-Saharan Africa      NaN     0.20200  2019           0.575
#
#      happiness_score  happiness_rank  log_gdp_per_capita  \
# 0              7.587             1.0             1.39651
# ...

# %%
filled_region = df_modified[df_modified['region'].notnull()]

# %%
filled_region['region'].values
# Out:
# array(['Western Europe', 'Western Europe', 'Western Europe',
#        'Western Europe', 'North America', 'Western Europe',
#        'Western Europe', 'Western Europe', 'Australia and New Zealand',
#        'Australia and New Zealand', 'Middle East and Northern Africa',
#        'Latin America and Caribbean', 'Western Europe',
#        'Latin America and Caribbean', 'North America',
#        'Latin America and Caribbean', 'Western Europe', 'Western Europe',
#        'Western Europe', 'Middle East and Northern Africa',
#        'Western Europe', 'Middle East and Northern Africa',
#        'Latin America and Caribbean', 'Southeastern Asia',
#        'Latin America and Caribbean', 'Western Europe',
#        'Latin America and Caribbean', 'Middle East and Northern Africa',
#        'Western Europe', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'Latin America and Caribbean',
#        'Latin America and Caribbean', 'Southeastern Asia',
# ...

# %%
df_mod[df_mod['country'] == 'China']
# Out:
#            region    family  generosity  year  social_support  \
# 83   Eastern Asia  0.946750    0.081850  2015             NaN
# 240  Eastern Asia  0.793810    0.049590  2016             NaN
# 393  Eastern Asia  1.160837    0.028807  2017             NaN
# 555  Eastern Asia       NaN    0.029000  2018           1.142
# 718  Eastern Asia       NaN    0.058000  2019           1.125
#
#      happiness_score  happiness_rank  log_gdp_per_capita  \
# 83             5.140            84.0            0.890120
# 240            5.245            83.0            1.027800
# 393            5.273            79.0            1.081166
# 555            5.246            86.0            0.989000
# 718            5.191            93.0            1.029000
#
#      healthy_life_expectancy  perceptions_of_corruption  dystopia_residual  \
# 83                  0.816580                   0.027810           1.860400
# 240                 0.735610                   0.027450           2.170870
# ...

# %%
region_counts = df_mod.groupby('country')['region'].nunique()

# %%
region_counts
# Out:
# country
# Afghanistan    1
# Albania        1
# Algeria        1
# Angola         1
# Argentina      1
#               ..
# Venezuela      1
# Vietnam        1
# Yemen          1
# Zambia         1
# Zimbabwe       1
# Name: region, Length: 170, dtype: int64

# %%
conflicting_regions = region_counts[region_counts > 1]

# %%
conflicting_regions
# Out:
# Series([], Name: region, dtype: int64)
